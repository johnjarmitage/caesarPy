# %% [markdown]
# # Plot precipitation history from Sithas Catchment (Bouzi Station)

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
file = '/work/armitagj/runs/caesar-explore/sithas/input_data/Chalkio_station.txt'
chalkio = pd.read_csv(file, sep=' |,', index_col=False, comment='#')
file = '/work/armitagj/runs/caesar-explore/sithas/input_data/Bouzi_station.txt'
bouzi = pd.read_csv(file, sep=' |,', index_col=False, comment='#')
# Out:
# /work/armitagj/miniconda3/envs/caesarpy/lib/python3.7/site-packages/ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#
# /work/armitagj/miniconda3/envs/caesarpy/lib/python3.7/site-packages/ipykernel_launcher.py:4: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   after removing the cwd from sys.path.

# %%
chalkio = chalkio.set_index('date')
bouzi = bouzi.set_index('date')
bouzi.head(3)
# Out:
#              time  rainfall
# date
# 1964-12-01  08:00       0.3
# 1964-12-02  08:00      14.7
# 1964-12-03  08:00       6.8

# %%
sns.set(rc={'figure.figsize':(20, 4)})

# %%
plt.figure()
ax = chalkio['rainfall'].plot(linewidth=0.5)
ax.set_ylabel('Precipitation (mm)')
plt.savefig('chalkio.png')
plt.show()

# %%
plt.figure()
ax = bouzi['rainfall'].plot(linewidth=0.5)
ax.set_ylabel('Precipitation (mm)')
plt.savefig('bouzi.png')
plt.show()

# %%
np.savetxt('/work/armitagj/runs/caesar-explore/sithas/input_data/Chalkio_rain.txt', chalkio.rainfall/24)

# %%
60*24
# Out:
# 1440

# %%
710/60
# Out:
# 11.833333333333334

# %% [markdown]
# # Plout output

# %%
file = '/work/armitagj/runs/caesar-explore/sithas/results_1/Sithas_v6_50_100days.dat'
sithas = pd.read_csv(file, sep=' ', index_col=False,
                     names=['Time Step', 'Qw(actual)', 'Qw(expected)', 'Blank', 'Qs', 'Qs1', 'Qs2', 'Qs3', 'Qs4'])
sithas
# Out:
#     Time Step  Qw(actual)  Qw(expected)  Blank            Qs          Qs1  \
# 0           1    0.000109      3.233561    0.0      0.000000     0.000000
# 1           2    0.007253      5.129772    0.0      0.000000     0.000000
# 2           3    1.133302      8.936087    0.0   3000.700605  2079.011562
# 3           4    8.835247      5.754995    0.0  11307.967098   315.096055
# 4           5    2.291488      2.159809    0.0   4467.301837     0.009104
# ..        ...         ...           ...    ...           ...          ...
# 94         95    0.634574      0.661999    0.0   2023.246643     0.000000
# 95         96    0.532080      0.561806    0.0   1764.598389     0.000000
# 96         97    0.456654      0.487988    0.0   1231.228715     0.000000
# 97         98    0.445027      0.713281    0.0   1210.187482     0.000000
# 98         99    0.762947      1.014315    0.0   1769.366831     0.000000
#
#             Qs2          Qs3         Qs4
# 0      0.000000     0.000000    0.000000
# 1      0.000000     0.000000    0.000000
# 2    743.396600   167.178366   11.114076
# 3   8849.297319  2009.696194  133.877529
# 4   3508.133736   889.677210   69.481787
# ..          ...          ...         ...
# 94  1648.768446   353.425588   21.052609
# 95  1430.977564   314.498269   19.122556
# 96   981.095789   234.159414   15.973512
# 97   967.993092   226.746970   15.447420
# 98  1394.186469   348.125255   27.055107
#
# [99 rows x 9 columns]

# %%
sns.set(rc={'figure.figsize':(15, 15)})
plt.figure()
cols_plot = ['Qw(actual)', 'Qw(expected)', 'Qs', 'Qs1', 'Qs2', 'Qs3', 'Qs4']
axes = sithas[cols_plot].plot(marker='.', alpha=0.5, subplots=True)
i = 0
for ax in axes:
    ax.set_ylabel(cols_plot[i])
    i += 1
plt.savefig('chalkio_first97days.png')
plt.show()

# %%
file = '/work/armitagj/runs/caesar-explore/sithas/results_2/Sithas_v6_50_100days.dat'
sithas = pd.read_csv(file, sep=' ', index_col=False,
                     names=['Time Step', 'Qw(actual)', 'Qw(expected)', 'Blank', 'Qs', 'Qs1', 'Qs2', 'Qs3', 'Qs4'])
sithas
# Out:
#     Time Step  Qw(actual)  Qw(expected)  Blank            Qs          Qs1  \
# 0           1    0.000109      3.233561    0.0      0.000000     0.000000
# 1           2    0.007253      5.129772    0.0      0.000000     0.000000
# 2           3    1.133301      8.936087    0.0   3000.697159  2079.008996
# 3           4    8.835250      5.754995    0.0  11307.969302   315.095141
# 4           5    2.291487      2.159809    0.0   4467.333809     0.009104
# ..        ...         ...           ...    ...           ...          ...
# 94         95    0.634778      0.662004    0.0   2023.536569     0.000000
# 95         96    0.532147      0.561794    0.0   1738.593493     0.000000
# 96         97    0.456266      0.487985    0.0   1232.698336     0.000000
# 97         98    0.444229      0.713285    0.0   1212.619232     0.000000
# 98         99    0.763177      1.014336    0.0   1765.321638     0.000000
#
#             Qs2          Qs3         Qs4
# 0      0.000000     0.000000    0.000000
# 1      0.000000     0.000000    0.000000
# 2    743.395895   167.178203   11.114065
# 3   8849.300412  2009.696281  133.877468
# 4   3508.174344   889.670899   69.479462
# ..          ...          ...         ...
# 94  1648.509767   353.971041   21.055761
# 95  1409.209889   310.476345   18.907259
# 96   981.355897   235.060030   16.282409
# 97   969.604018   227.597492   15.417722
# 98  1390.286376   347.703546   27.331716
#
# [99 rows x 9 columns]

# %%
sns.set(rc={'figure.figsize':(15, 15)})
plt.figure()
cols_plot = ['Qw(actual)', 'Qw(expected)', 'Qs', 'Qs1', 'Qs2', 'Qs3', 'Qs4']
axes = sithas[cols_plot].plot(marker='.', alpha=0.5, subplots=True)
i = 0
for ax in axes:
    ax.set_ylabel(cols_plot[i])
    i += 1
plt.savefig('chalkio_first97days.png')
plt.show()

# %%
file = '/work/armitagj/runs/caesar-explore/sithas/results/Sithas_v6_50_100days.dat'
sithas = pd.read_csv(file, sep=' ', index_col=False,
                     names=['Time Step', 'Qw(actual)', 'Qw(expected)', 'Blank', 'Qs', 'clay', 'silt', 'sand', 'gravel'])
sithas
# Out:
#       Time Step  Qw(actual)  Qw(expected)  Blank            Qs         clay  \
# 0             1    0.000109      3.233561    0.0      0.000000     0.000000
# 1             2    0.007253      5.129772    0.0      0.000000     0.000000
# 2             3    1.133302      8.936087    0.0   3000.700578  2079.011547
# 3             4    8.835247      5.754995    0.0  11307.967115   315.096064
# 4             5    2.291488      2.159809    0.0   4467.301833     0.009104
# ...         ...         ...           ...    ...           ...          ...
# 1036       1037    0.299665      0.313675    0.0     21.340708     0.000000
# 1037       1038    0.279918      0.289269    0.0     24.062171     0.000000
# 1038       1039    0.261234      0.268388    0.0     14.254862     0.000000
# 1039       1040    0.244043      0.250320    0.0      1.790658     0.000000
# 1040       1041    3.711300     10.940577    0.0   4417.135865     8.621431
#
#              silt         sand      gravel
# 0        0.000000     0.000000    0.000000
# 1        0.000000     0.000000    0.000000
# 2      743.396591   167.178364   11.114076
# 3     8849.297325  2009.696196  133.877530
# 4     3508.133732   889.677210   69.481787
# ...           ...          ...         ...
# 1036    14.823216     5.955040    0.562452
# 1037    19.042664     4.545984    0.473523
# 1038    11.571410     2.459240    0.224213
# 1039     1.309046     0.419295    0.062317
# 1040  3558.032022   794.065071   56.417341
#
# [1041 rows x 9 columns]

# %%
sns.set(rc={'figure.figsize':(15, 15)})
plt.figure()
cols_plot = ['Qw(actual)', 'Qw(expected)', 'Qs', 'clay', 'silt', 'sand', 'gravel']
axes = sithas[cols_plot].plot(marker='.', alpha=0.5, subplots=True)
i = 0
for ax in axes:
    ax.set_ylabel(cols_plot[i])
    i += 1
plt.savefig('chalkio_first1000days.png')
plt.show()
